# %% [markdown]
# ## Count Occurences of Anagrams

# %% [markdown]
# Given a word pat and a text txt. Return the count of the occurrences of anagrams of the word in the text.
#
# ```bash
# Input: txt = "forxxorfxdofr", pat = "for"
# Output: 3
# Explanation: for, orf and ofr appears in the txt, hence answer is 3.
#
# Input: txt = "aabaabaa", pat = "aaba"
# Output: 4
# Explanation: aaba is present 4 times in txt.
# ```

# %% [markdown]
# ```cpp
#
# 1. store count of each character in pat, use int array of size 26 -> count
# 2. i = 0, j = 0
#  while(j < n) {
#     int idx = txt[j]-'a';
#     count[idx]--;
#
#     if(j - i + 1 == k) {
#         if(allZero(count)) {
#             result++;
#         }
#
#         count[txt[i]-'a']++;
#         i++;
#     }
#     j++;
# }
#
# ```

# %% [markdown]
# ## 209. Minimum Size Subarray Sum

# %% [markdown]
# Given an array of positive integers nums and a positive integer target, return the minimal length of a subarray whose sum is greater than or equal to target. If there is no such subarray, return 0 instead.
#
# ```bash
# Input: target = 7, nums = [2,3,1,2,4,3]
# Output: 2
# Explanation: The subarray [4,3] has the minimal length under the problem constraint.
# ```

# %% [markdown]
# ```python
# def minSubArrayLen(self, target: int, nums: List[int]) -> int:
#     i=0
#     window = float('inf')
#     sm = 0
#     for j in range(len(nums)):
#         sm += nums[j]
#         while sm >=target:
#             window = min(window,j-i+1)
#             sm -= nums[i]
#             i+=1
#     return window if window!=float('inf') else 0
# ```

# %% [markdown]
# ## First negative in every window of size k

# %% [markdown]
# Given an array arr[]  and a positive integer k, find the first negative integer for each and every window(contiguous subarray) of size k.
#
# Note: If a window does not contain a negative integer, then return 0 for that window.
#
#         Examples:
#
#         Input: arr[] = [-8, 2, 3, -6, 10] , k = 2
#         Output: [-8, 0, -6, -6]
#         Explanation:
#         Window [-8, 2] First negative integer is -8.
#         Window [2, 3] No negative integers, output is 0.
#         Window [3, -6] First negative integer is -6.
#         Window [-6, 10] First negative integer is -6.
#         Input: arr[] = [12, -1, -7, 8, -15, 30, 16, 28] , k = 3
#         Output: [-1, -1, -7, -15, -15, 0]
#         Explanation:
#         Window [12, -1, -7] First negative integer is -1.
#         Window [-1, -7, 8] First negative integer is -1.
#         Window [-7, 8, -15] First negative integer is -7.
#         Window [8, -15, 30] First negative integer is -15.
#         Window [-15, 30, 16] First negative integer is -15.
#         Window [30, 16, 28] No negative integers, output is 0.
#         Input: arr[] = [12, 1, 3, 5] , k = 3
#         Output: [0, 0]
#         Explanation:
#         Window [12, 1, 3] No negative integers, output is 0.
#         Window [1, 3, 5] No negative integers, output is 0.

# %% [markdown]
# ```python
#
# approach-1
#
# 1. loop over j : check if arr[j] < 0 then push index to dq
# 2. if window size == K : get neg_idx # First negative in window or 0,pop out dq[0]
#  2.1 push arr[neg_idx] in result
#  2.2 if arr[i] < 0 and not dq.empty : we have to remove it since it out of window
#  2.3 increment i # for next window
#
# approach-2
#
# def printFirstNegativeInteger(A, K):
#     deq = deque() # Store index
#     result = []
#     N = len(A)
#
#     # Process first window of size K
#     for i in range(K):
#         if A[i] < 0:
#             deq.append(i)
#
#     # Process rest of the windows
#     for i in range(K, N):
#         # Add result for previous window
#         if deq:
#             result.append(A[deq[0]])
#         else:
#             result.append(0)
#
#         # Remove elements out of this window
#         while deq and deq[0] < i - K + 1:
#             deq.popleft()
#
#         # Add new element if negative
#         if A[i] < 0:
#             deq.append(i)
#
#     # Handle last window
#     if deq:
#         result.append(A[deq[0]])
#     else:
#         result.append(0)
#
#     return result
#
# ```

# %% [markdown]
# ## 76. Minimum Window Substring

# %% [markdown]
# Given two strings s and t of lengths m and n respectively, return the minimum window substring of s such that every character in t (including duplicates) is included in the window. If there is no such substring, return the empty string "".
#
# ```bash
# Input: s = "ADOBECODEBANC", t = "ABC"
# Output: "BANC"
#
# Input: s = "a", t = "a"
# Output: "a"
#
# Input: s = "a", t = "aa"
# Output: ""
# ```

# %% [markdown]
# ```python
#
# """
# 1. count freq of t in map_t
# 2. we keep reducing the count of map_t if it's present in s, also reduce require_count
# 3. while require_count==0
#     3.1 we store the window size & i pointer (will need for window re-construction later)
#     3.2 if current character is in map_t , we increase the count since it's outside the window
# 4. window = s[start:start+window] if possible
# """
#
# def minWindow(self, s: str, t: str) -> str:
#
#         if not s or not t:
#             return ""
#
#         mp_t = {}
#         for ch in t:
#             mp_t[ch] = 1+mp_t.get(ch,0)
#         count_req = len(t)
#         i = 0
#         window = float('inf')
#         start = 0
#
#         for j in range(len(s)):
#             # If s[j] is a character we need AND we haven't already
#             # satisfied the count for this specific character:
#             if s[j] in mp_t:
#                 if mp_t[s[j]] > 0:
#                     count_req -= 1
#                 mp_t[s[j]] -= 1
#             while count_req == 0:
#                 if window > j - i + 1:
#                     window = j - i + 1
#                     start = i
#                 if s[i] in mp_t:
#                     mp_t[s[i]] += 1
#                     # If the character count goes above 0, it means
#                     # the window is no longer valid
#                     if mp_t[s[i]] > 0:
#                         count_req += 1
#                 i += 1
#         return "" if window==float('inf') else s[start:start+window]
# ```

# %% [markdown]
# ## 1456. Maximum Number of Vowels in a Substring of Given Length

# %% [markdown]
# Given a string s and an integer k, return the maximum number of vowel letters in any substring of s with length k.
#
# ```bash
#
# Input: s = "abciiidef", k = 3
# Output: 3
# Explanation: The substring "iii" contains 3 vowel letters.
#
# Input: s = "leetcode", k = 3
# Output: 2
# Explanation: "lee", "eet" and "ode" contain 2 vowels.
# ```

# %% [markdown]
# ```python
# def maxVowels(self, s: str, k: int) -> int:
#     n = len(s)
#     if n < k:
#         return 0
#     vowel_count = 0
#     max_vowel = 0
#     for i in range(k):
#         if s[i] in 'aeiou':
#             vowel_count +=1
#     max_vowel = max(max_vowel,vowel_count)
#     i = k
#     while i < n:
#         if s[i-k] in 'aeiou':
#             vowel_count -=1
#         if s[i] in 'aeiou':
#             vowel_count +=1
#         max_vowel = max(max_vowel,vowel_count)
#         if max_vowel==k: # can't be more than fixed window = k
#             return k
#         i+=1
#     return max_vowel
# ```

# %% [markdown]
# ## 219. Contains Duplicate II

# %% [markdown]
# Given an integer array nums and an integer k, return true if there are two distinct indices i and j in the array such that nums[i] == nums[j] and abs(i - j) <= k.
#
# ```bash
# Input: nums = [1,2,3,1], k = 3
# Output: true
#
# Input: nums = [1,2,3,1,2,3], k = 2
# Output: false
# ```
#
# ```python
# def containsNearbyDuplicate(self, nums: List[int], k: int) -> bool:
#     st = set()
#     i = 0
#     for j in range(len(nums)):
#         # outside window
#         if abs(j-i)>k:
#             st.discard(nums[i])
#             i+=1
#         # have seen in past - window found
#         if nums[j] in st:
#             return True
#         st.add(nums[j])
#     return False
# ```

# %% [markdown]
# ## 2444. Count Subarrays With Fixed Bounds

# %% [markdown]
# You are given an integer array nums and two integers minK and maxK.
# A fixed-bound subarray of nums is a subarray that satisfies the following conditions:
#
# The minimum value in the subarray is equal to minK.
# The maximum value in the subarray is equal to maxK.
# Return the number of fixed-bound subarrays.
#
# ```bash
# Input: nums = [1,3,5,2,7,5], minK = 1, maxK = 5
# Output: 2
# Explanation: The fixed-bound subarrays are [1,3,5] and [1,3,5,2].
#
# Input: nums = [1,1,1,1], minK = 1, maxK = 1
# Output: 10
# Explanation: Every subarray of nums is a fixed-bound subarray. There are 10 possible subarrays.
# ```

# %% [markdown]
# ```python
#
# """
# curlpitIdx : outside of the range of [minK,maxK]
# To find out from where we can start our subarray(s)
#     - rangeStartIdx : find minimum starting point between [minK,maxK] position
#     - rangeStartIdx - curlpitIdx : tells
#
#     [6,| 3,5,2,1] - curlpitIdx=0,rangeStartIdx=2, so we can start subarray rangeStartIdx-1
#
# """
#
# def countSubarrays(self, nums: List[int], minK: int, maxK: int) -> int:
#     minKPos,maxKPos = -1, -1
#     curlpitIdx = -1
#     res = 0
#     for i in range(len(nums)):
#         if nums[i]<minK or nums[i]>maxK:
#             curlpitIdx = i
#         if nums[i]==minK:
#             minKPos = i
#         if nums[i]==maxK:
#             maxKPos = i
#
#         rangeStartIdx = min(minKPos,maxKPos)
#         canExtend = rangeStartIdx - curlpitIdx
#         res += 0 if canExtend<=0 else canExtend
#     return res
#
# ```

# %% [markdown]
# ## 2090. K Radius Subarray Averages

# %% [markdown]
# The k-radius average for a subarray of nums centered at some index i with the radius k is the average of all elements in nums between the indices i - k and i + k (inclusive). If there are less than k elements before or after the index i, then the k-radius average is -1.
#
# Build and return an array avgs of length n where avgs[i] is the k-radius average for the subarray centered at index i.
#
#     Input: nums = [7,4,3,9,1,8,5,2,6], k = 3
#     Output: [-1,-1,-1,5,4,4,-1,-1,-1]
#     Explanation:
#     - avg[0], avg[1], and avg[2] are -1 because there are less than k elements before each index.
#     - The sum of the subarray centered at index 3 with radius 3 is: 7 + 4 + 3 + 9 + 1 + 8 + 5 = 37.
#     Using integer division, avg[3] = 37 / 7 = 5.
#     - For the subarray centered at index 4, avg[4] = (4 + 3 + 9 + 1 + 8 + 5 + 2) / 7 = 4.
#     - For the subarray centered at index 5, avg[5] = (3 + 9 + 1 + 8 + 5 + 2 + 6) / 7 = 4.
#     - avg[6], avg[7], and avg[8] are -1 because there are less than k elements after each index.
#     Example 2:
#
#     Input: nums = [100000], k = 0
#     Output: [100000]
#     Explanation:
#     - The sum of the subarray centered at index 0 with radius 0 is: 100000.
#     avg[0] = 100000 / 1 = 100000.
#     Example 3:
#
#     Input: nums = [8], k = 100000
#     Output: [-1]
#     Explanation:
#     - avg[0] is -1 because there are less than k elements before and after index 0.

# %% [markdown]
# ```python
#
# ## Approach - 1
#
# At each step we need the avg of 2k+1 elements
#
# 1. create pref_sum array
# 2. value at k-th place = pref_sum[i+k]-pref_sum[i-k-1]//(2*k+1)
#
# def getAverages(self, nums: List[int], k: int) -> List[int]:
#     n = len(nums)
#     if k==0:
#         return nums
#     result = [-1 for _ in range(n)]
#     if n < 2*k+1:
#         return result
#     pref_sum = [0 for _ in range(n)]
#     pref_sum[0] = nums[0]
#     for i in range(1,n):
#         pref_sum[i] = pref_sum[i-1]+nums[i]
#
#     for i in range(k,n-k):
#         if i-k > 0:
#             result[i] = (pref_sum[i+k]-pref_sum[i-k-1])//(2*k+1)
#         else:
#             result[i]=pref_sum[i+k]//(2*k+1) # i=k,i-k==0,for 1st element
#     return result
#
#
# # Approach -2
#
# window_sum = 0
# left = 0
# right = 2*k
# i = k
# # make sure to use different variable than i
# for x in range(0,2*k+1):
#     window_sum +=nums[x]
# result[i] = window_sum // (2*k+1)
# i+=1
# right+=1
# while right < n:
#     window_sum = window_sum-nums[left]+nums[right]
#     result[i] = window_sum // (2*k+1)
#     left+=1
#     right+=1
#     i+=1
#
# ```
